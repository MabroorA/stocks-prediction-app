# %%
## libraries

import requests
import pandas as pd

# %%
# flask end point which recieves data from frontend
response_get = requests.get('http://192.168.0.17:5000/test-ticker-data')
# !!Working

data = response_get.json()
print(data)
# Out:
# {'historical': [{'adjClose': 47.41, 'change': 0.2375, 'changeOverTime': 0.0050526, 'changePercent': 0.50526, 'close': 47.74, 'date': '2019-04-05', 'high': 47.91, 'label': 'April 05, 19', 'low': 47.13, 'open': 47.5, 'unadjustedVolume': 48174596, 'volume': 48174596, 'vwap': 47.57}, {'adjClose': 47.62, 'change': 0.5175, 'changeOverTime': 0.011, 'changePercent': 1.1, 'close': 47.95, 'date': '2019-04-08', 'high': 48.2, 'label': 'April 08, 19', 'low': 47.19, 'open': 47.43, 'unadjustedVolume': 42419392, 'volume': 42419392, 'vwap': 47.6925}, {'adjClose': 46.99, 'change': -0.295, 'changeOverTime': -0.0060912, 'changePercent': -0.60912, 'close': 47.32, 'date': '2019-04-09', 'high': 47.72, 'label': 'April 09, 19', 'low': 46.89, 'open': 47.61, 'unadjustedVolume': 43997280, 'volume': 43997280, 'vwap': 47.385}, {'adjClose': 47.7, 'change': 0.7175, 'changeOverTime': 0.0152, 'changePercent': 1.52, 'close': 48.03, 'date': '2019-04-10', 'high': 48.29, 'label': 'April 10, 19', 'low': 47.26, 'open': 47.31, 'unadjustedVolume': 44477228, 'volume': 44477228, 'vwap': 47.7225}, {'adjClose': 47.56, 'change': -0.165, 'changeOverTime': -0.0033299, 'changePercent': -0.33299, 'close': 47.89, 'date': '2019-04-11', 'high': 48.37, 'label': 'April 11, 19', 'low': 47.39, 'open': 48.05, 'unadjustedVolume': 37460148, 'volume': 37460148, 'vwap': 47.925}, {'adjClose': 47.18, 'change': -0.7725, 'changeOverTime': -0.0162, 'changePercent': -1.62, 'close': 47.5, 'date': '2019-04-12', 'high': 48.32, 'label': 'April 12, 19', 'low': 47.42, 'open': 48.28, 'unadjustedVolume': 47170656, 'volume': 47170656, 'vwap': 47.88}, {'adjClose': 45.86, 'change': -1.25, 'changeOverTime': -0.0264, 'changePercent': -2.64, 'close': 46.18, 'date': '2019-04-15', 'high': 47.48, 'label': 'April 15, 19', 'low': 45.78, 'open': 47.43, 'unadjustedVolume': 44009380, 'volume': 44009380, 'vwap': 46.7175}, {'adjClose': 46.73, 'change': 0.4825, 'changeOverTime': 0.0103, 'changePercent': 1.03, 'close': 47.05, 'date': '2019-04-16', 'high': 47.24, 'label': 'April 16, 19', 'low': 46.24, 'open': 46.57, 'unadjustedVolume': 39496364, 'volume': 39496364, 'vwap': 46.775}, {'adjClose': 46.5, 'change': -0.5825, 'changeOverTime': -0.0124, 'changePercent': -1.24, 'close': 46.82, 'date': '2019-04-17', 'high': 47.62, 'label': 'April 17, 19', 'low': 46.6, 'open': 47.41, 'unadjustedVolume': 35100272, 'volume': 35100272, 'vwap': 47.1125}, {'adjClose': 46.26, 'change': -0.315, 'changeOverTime': -0.0066112, 'changePercent': -0.66112, 'close': 46.58, 'date': '2019-04-18', 'high': 47.23, 'label': 'April 18, 19', 'low': 46.3, 'open': 46.89, 'unadjustedVolume': 38098816, 'volume': 38098816, 'vwap': 46.75}, {'adjClose': 46.8, 'change': 0.78, 'changeOverTime': 0.0168, 'changePercent': 1.68, 'close': 47.12, 'date': '2019-04-22', 'high': 47.28, 'label': 'April 22, 19', 'low': 46.02, 'open': 46.34, 'unadjustedVolume': 27993552, 'volume': 27993552, 'vwap': 46.69}, {'adjClose': 47.34, 'change': 0.4175, 'changeOverTime': 0.0088889, 'changePercent': 0.88889, 'close': 47.67, 'date': '2019-04-23', 'high': 47.98, 'label': 'April 23, 19', 'low': 47.15, 'open': 47.25, 'unadjustedVolume': 34685524, 'volume': 34685524, 'vwap': 47.5125}, {'adjClose': 47.47, 'change': 0.02, 'changeOverTime': 0.0004186728, 'changePercent': 0.04186728, 'close': 47.79, 'date': '2019-04-24', 'high': 48.2, 'label': 'April 24, 19', 'low': 47.16, 'open': 47.77, 'unadjustedVolume': 31820480, 'volume': 31820480, 'vwap': 47.73}, {'adjClose': 46.41, 'change': -0.66, 'changeOverTime': -0.0139, 'changePercent': -1.39, 'close': 46.73, 'date': '2019-04-25', 'high': 47.61, 'label': 'April 25, 19', 'low': 45.93, 'open': 47.39, 'unadjustedVolume': 49929748, 'volume': 49929748, 'vwap': 46.915}, {'adjClose': 44.22, 'change': -0.655, 'changeOverTime': -0.0146, 'changePercent': -1.46, 'close': 44.52, 'date': '2019-04-26', 'high': 45.22, 'label': 'April 26, 19', 'low': 43.33, 'open': 45.18, 'unadjustedVolume': 86898916, 'volume': 86898916, 'vwap': 44.5625}, {'adjClose': 44.53, 'chan ...

# %%
df = pd.DataFrame(data["historical"])
df.head()
# Out:
#    adjClose  change  changeOverTime  changePercent  close        date   high  \
# 0     47.41  0.2375        0.005053        0.50526  47.74  2019-04-05  47.91
# 1     47.62  0.5175        0.011000        1.10000  47.95  2019-04-08  48.20
# 2     46.99 -0.2950       -0.006091       -0.60912  47.32  2019-04-09  47.72
# 3     47.70  0.7175        0.015200        1.52000  48.03  2019-04-10  48.29
# 4     47.56 -0.1650       -0.003330       -0.33299  47.89  2019-04-11  48.37
#
#           label    low   open  unadjustedVolume    volume     vwap
# 0  April 05, 19  47.13  47.50          48174596  48174596  47.5700
# 1  April 08, 19  47.19  47.43          42419392  42419392  47.6925
# 2  April 09, 19  46.89  47.61          43997280  43997280  47.3850
# 3  April 10, 19  47.26  47.31          44477228  44477228  47.7225
# 4  April 11, 19  47.39  48.05          37460148  37460148  47.9250
